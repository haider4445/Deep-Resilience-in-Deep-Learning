# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/haider4445/FastUndetectableAttack.git
# Out:
# Cloning into 'FastUndetectableAttack'...
# remote: Enumerating objects: 2125, done.
# remote: Counting objects: 100% (2125/2125), done.
# remote: Compressing objects: 100% (1916/1916), done.
# remote: Total 2125 (delta 287), reused 2047 (delta 209), pack-reused 0
# Receiving objects: 100% (2125/2125), 31.20 MiB | 30.34 MiB/s, done.
# Resolving deltas: 100% (287/287), done.

# %%
# %cd FastUndetectableAttack/
# Out:
# /content/FastUndetectableAttack

# %%
# !wget http://www.atarimania.com/roms/Roms.rar && unrar x Roms.rar && unzip Roms/ROMS.zip
# !unzip ROMS.zip
# !pip install gym[atari]
# !python -m atari_py.import_roms /content/FastUndetectableAttack
# Out:
# --2021-08-24 02:22:45--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11128004 (11M) [application/x-rar-compressed]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  10.61M   626KB/s    in 18s
#
# 2021-08-24 02:23:03 (604 KB/s) - ‘Roms.rar’ saved [11128004/11128004]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Roms.rar
#
#   OK
#   OK
# All OK
# unzip:  cannot find or open Roms/ROMS.zip, Roms/ROMS.zip.zip or Roms/ROMS.zip.ZIP.
# Archive:  ROMS.zip
#    creating: ROMS/
#   inflating: ROMS/128 in 1 Game Select ROM (128 in 1) (Unknown) ~.bin
#   inflating: ROMS/2 Pak Special - Cavern Blaster, City War (1992) (HES) (773-867) (PAL).bin
# ...

# %%
# %load_ext tensorboard

# %%
# !apt-get install -y xvfb x11-utils

# !pip install pyvirtualdisplay==0.2.* \
             PyOpenGL==3.1.* \
             PyOpenGL-accelerate==3.1.*

# !pip install gym[box2d]==0.17.*
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libxxf86dga1
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils xvfb
# 0 upgraded, 3 newly installed, 0 to remove and 40 not upgraded.
# Need to get 994 kB of archives.
# After this operation, 2,981 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.9 [784 kB]
# Fetched 994 kB in 1s (1,062 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# ...

# %% [markdown]
# # PGD Targeted

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType pgd --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 1 --strategy allSteps
# Out:
# Streaming output truncated to the last 5000 lines.
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType pgd --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 20 --strategy allSteps
# Out:
# Streaming output truncated to the last 5000 lines.
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  399.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType cw --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 20 --strategy allSteps

# %% [markdown]
# #

# %% [markdown]
# #DIFGSM Targeted

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType difgsm --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 1 --strategy allSteps
# Out:
# Streaming output truncated to the last 5000 lines.
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType mifgsm --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 1 --strategy allSteps
# Out:
# Streaming output truncated to the last 5000 lines.
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# Attack mode is changed to 'targeted.'
# Reward so far:  0.0
# Done status:  False
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType apgd --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='apgd', stepsRFGSM=1, strategy='allSteps', targeted=1, totalgames=1)
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType apgdt --attack 1 --stepsRFGSM 1 --targeted 1 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='apgdt', stepsRFGSM=1, strategy='allSteps', targeted=1, totalgames=1)
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# Done status:  False
# Reward so far:  0.0
# ...

# %% [markdown]
# # FGSM targeted test Action = DRL

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType fgsmt --attack 1 --stepsRFGSM 1 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='fgsmt', stepsRFGSM=1, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...

# %% [markdown]
# # FGSM targeted test Action = 1

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType fgsmt --attack 1 --stepsRFGSM 1 --totalgames 1 --strategy allSteps

# %% [markdown]
# # RFGSM targeted test Action = DRL

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 1 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='rfgsmt', stepsRFGSM=1, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 2 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='rfgsmt', stepsRFGSM=2, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 3 --totalgames 1 --strategy allSteps
# Out:
# Streaming output truncated to the last 5000 lines.
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# Done status:  False
# -4.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 4 --totalgames 1 --strategy allSteps
# Out:
# Streaming output truncated to the last 5000 lines.
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# 3.0
# Done status:  False
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 5 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='rfgsmt', stepsRFGSM=5, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 6 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='rfgsmt', stepsRFGSM=6, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType rfgsmt --attack 1 --stepsRFGSM 7 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='rfgsmt', stepsRFGSM=7, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...

# %% [markdown]
# #CW targeted test Action = DRL

# %%
# !python attack-dqn.py --Path /content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat --env PongNoFrameskip-v4 --perturbationType cwt --attack 1 --stepsRFGSM 1 --totalgames 1 --strategy allSteps
# Out:
# Namespace(Path='/content/gdrive/MyDrive/testfolder/PongNoFrameskip-v4-best.dat', alphaRFGSM=0.03137254901960784, attack=1, env='PongNoFrameskip-v4', epsRFGSM=0.06274509803921569, perturbationType='cwt', stepsRFGSM=1, strategy='allSteps', totalgames=1)
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# Done status:  False
# 0.0
# ...
